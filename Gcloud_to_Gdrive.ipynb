# %% [markdown]
# <a href="https://colab.research.google.com/github/ylkim1947/Project7-Car_color_classfication/blob/main/Gcloud_to_Gdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 구글 드라이브에 접속

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 구글 클라우드에 접속
#
# Project ID 필요

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'ylkim-cp2'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://codestates_cp2_cars/

# %% [markdown]
# 구글 클라우드 --> 구글 드라이브
#
# !gsutil -m cp -R gs://{클라우드폴더} /content/gdrive/MyDrive/{드라이브폴더}
#
# gsutil: 라이브러리
#
# -m : 멀티스레딩(속도 업)
#
# cp: 복사

# %%
bucket_name = 'gs://codestates_cp2_cars/'
dataset_path ='/content/drive/MyDrive/Colab Notebooks/project_cp2'

# !gsutil -m cp -R gs://codestates_cp2_cars/ /content/drive/MyDrive/cp2
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# sh: 0: getcwd() failed: Transport endpoint is not connected
# [2022-11-21 10:42:19,700] {ultratb.py:155} ERROR - Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-24-989669780e11>", line 4, in <module>
#     get_ipython().system('gsutil -m cp -R gs://codestates_cp2_cars/ /content/gdrive/MyDrive/cp2')
#   File "/usr/local/lib/python3.7/dist-packages/google/colab/_shell.py", line 95, in system
#     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
# ...

# %% [markdown]
# 구글 드라이브에서 알집 해제

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/원천데이터/
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/원천데이터/TS1.zip"
#!unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/원천데이터/TS2.zip"
#!unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/원천데이터/TS3.zip_.gstmp"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/원천데이터/TS4.zip"
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/원천데이터

# %%
ls
# Out:
# AU_아우디/  FO_포드/      LA_랜드로버/  RE_르노/      TS1.zip         VV_볼보/
# BE_벤츠/    GE_제네시스/  LE_렉서스/    RS_르노삼성/  TS3.zip_.gstmp
# BM_BMW/     HO_혼다/      MI_미니/      SS_쌍용/      TS4.zip
# CH_쉐보레/  KI_기아/      NI_닛산/      TO_토요타/    VO_폭스바겐/

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/라벨링데이터/

# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/라벨링데이터/TL1.zip"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/라벨링데이터/TL2.zip"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/라벨링데이터/TL3.zip"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/라벨링데이터/TL4.zip"
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/라벨링데이터
# replace HY_현대/025_i30/2017_빨강_트림A/C_210812_HY_025_17_RE_A_P_01_002.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/원천데이터/

# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/원천데이터/VS1.zip"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/원천데이터/VS2.zip"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/원천데이터/VS3.zip"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/원천데이터/VS4.zip"
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/원천데이터

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/라벨링데이터/

# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/라벨링데이터/VL1.zip"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/라벨링데이터/VL2.zip"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/라벨링데이터/VL3.zip"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/2.Validation/라벨링데이터/VL4.zip"
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars/091/01.데이터/1.Training/라벨링데이터

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars

# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/093.zip"
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars
# [/content/drive/MyDrive/cp2/codestates_cp2_cars/093.zip]
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/drive/MyDrive/cp2/codestates_cp2_cars/093.zip or
#         /content/drive/MyDrive/cp2/codestates_cp2_cars/093.zip.zip, and cannot find /content/drive/MyDrive/cp2/codestates_cp2_cars/093.zip.ZIP, period.

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/093
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars/093

# %%
ls
# Out:
# ^C

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training

#!unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/검정.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/black"
#!unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/회색.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/grey" 
# !unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/빨강.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/red"
#!unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/흰색.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/white"
#!unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/파랑.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/blue"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/red/C_211105_KI_060_20_RE_C_P_01_009.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/red/C_211105_KI_060_20_RE_C_P_01_010.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/red/C_211105_KI_060_20_RE_C_P_01_011.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/red/C_211105_KI_060_20_RE_C_P_01_013.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/red/C_211105_KI_060_20_RE_C_P_01_014.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/red/C_211105_KI_060_20_RE_C_P_01_015.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/red/C_211105_KI_060_20_RE_C_P_01_016.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training/red/C_211105_KI_060_20_RE_C_P_01_017.jpg
# ...

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation

# !unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/검정.zip"  -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/black"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/회색.zip"  -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/grey"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/빨강.zip"  -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/red"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/흰색.zip" -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/white"
# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/파랑.zip" -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/blue"
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation
# Archive:  /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/검정.zip
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/black/C_210802_HY_041_19_BK_A_P_01_052.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/black/C_210802_HY_041_19_BK_A_P_01_054.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/black/C_210802_HY_041_19_BK_A_T_03_006.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/black/C_210802_HY_064_18_BK_A_T_02_006.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/black/C_210806_GE_020_19_BK_A_P_01_013.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation/black/C_210806_GE_020_19_BK_A_P_01_014.jpg
# ...

# %%
ls
# Out:
# black/  grey/  파랑.zip  회색.zip  검정.zip  빨강.zip  흰색.zip

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation

# %%
import os 
JPG_ex = r'.jpg'
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training

dir = '/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training'
jpg_list = [file for file in os.listdir(dir) if file.endswith(JPG_ex)]
for f in jpg_list:
  print(f)
  os.remove(f)
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training

# %%
import os 
JPG_ex = r'.jpg'
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation

dir = '/content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation'
jpg_list = [file for file in os.listdir(dir) if file.endswith(JPG_ex)]
for f in jpg_list:
  os.remove(f)
# Out:
# /content/drive/MyDrive/cp2/codestates_cp2_cars/094/2.Validation

# %%
dir = '/content/drive/MyDrive/cp2/codestates_cp2_cars/094/1.Training'
os.listdir(dir)
# Out:
# ['검정.zip', '파랑.zip', '빨강.zip', '회색.zip', '흰색.zip']

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation

# !unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/2.Validation.zip"  -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/"
#!unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/회색.zip"  -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/grey"
#!unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/빨강.zip"  -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/red"
#!unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/흰색.zip" -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/white"
#!unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/파랑.zip" -d "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/blue"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#          continuing with "central" filename version
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/흰색/C_211202_CH_049_18_WH_C_T_03_003.jpg
# 흰색/C_211202_CH_049_18_WH_C_T_03_010.jpg:  mismatching "local" filename (эЭ░ьГЙ/C_211202_CH_049_18_WH_C_T_03_010.jpg),
#          continuing with "central" filename version
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/흰색/C_211202_CH_049_18_WH_C_T_03_010.jpg
# 흰색/C_211202_CH_061_19_WH_B_T_03_005.jpg:  mismatching "local" filename (эЭ░ьГЙ/C_211202_CH_061_19_WH_B_T_03_005.jpg),
#          continuing with "central" filename version
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/2.Validation/흰색/C_211202_CH_061_19_WH_B_T_03_005.jpg
# 흰색/C_211202_CH_061_19_WH_B_T_03_010.jpg:  mismatching "local" filename (эЭ░ьГЙ/C_211202_CH_061_19_WH_B_T_03_010.jpg),
#          continuing with "central" filename version
# ...

# %%
# %cd /content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training
#!unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/회색.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/grey" 
#!unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/흰색.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/white"
#!unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/빨강.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/red"

# !unzip -qq "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/검정.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/black"
# !unzip  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/파랑.zip" -d  "/content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/blue"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/blue/C_211111_KI_062_20_BL_A_T_03_011.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/blue/C_211111_KI_062_20_BL_A_T_03_013.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/blue/C_211111_KI_062_20_BL_A_T_03_014.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/blue/C_211111_KI_062_20_BL_A_T_03_015.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/blue/C_211111_KI_062_20_BL_A_T_03_016.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/blue/C_211111_KI_062_20_BL_A_T_03_017.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/blue/C_211111_KI_062_20_BL_A_T_03_019.jpg
#   inflating: /content/drive/MyDrive/cp2/codestates_cp2_cars/096/1.Training/blue/C_211111_KI_062_20_BL_A_T_03_021.jpg
# ...
